# %% [markdown]
# ## Pandas – Basic Maneuvers
#
# ### Data Operations with Pandas

# %% [markdown]
# ### Link to pandas documentation: https://pandas.pydata.org/pandas-docs/stable/reference

# %%
import pandas as pd
print('pandas: ',pd.__version__)
# Out:
# pandas:  1.3.4

# %%
import datetime
from pytz import timezone
print("Last run @{}".format(datetime.datetime.now(timezone('US/Pacific'))))
# Out:
# Last run @2022-01-24 17:59:31.833810-08:00

# %% [markdown]
# ### 1-Getting data in/out

# %%
df_cars = pd.read_csv("data/car-data/car-milage.csv")

# %% [markdown]
# ### 2-Basic Operations

# %%
df_cars.count()
# Out:
# mpg             32
# displacement    32
# hp              32
# torque          30
# CRatio          32
# RARatio         32
# CarbBarrells    32
# NoOfSpeed       32
# length          32
# width           32
# weight          32
# automatic       32
# dtype: int64

# %%
df_cars # This is a dataframe
# Out:
#       mpg  displacement   hp  torque  CRatio  RARatio  CarbBarrells  \
# 0   18.90         350.0  165   260.0    8.00     2.56             4
# 1   17.00         350.0  170   275.0    8.50     2.56             4
# 2   20.00         250.0  105   185.0    8.25     2.73             1
# 3   18.25         351.0  143   255.0    8.00     3.00             2
# 4   20.07         225.0   95   170.0    8.40     2.76             1
# 5   11.20         440.0  215   330.0    8.20     2.88             4
# 6   22.12         231.0  110   175.0    8.00     2.56             2
# 7   21.47         262.0  110   200.0    8.50     2.56             2
# 8   34.70          89.7   70    81.0    8.20     3.90             2
# 9   30.40          96.9   75    83.0    9.00     4.30             2
# 10  16.50         350.0  155   250.0    8.50     3.08             4
# 11  36.50          85.3   80    83.0    8.50     3.89             2
# 12  21.50         171.0  109   146.0    8.20     3.22             2
# 13  19.70         258.0  110   195.0    8.00     3.08             1
# 14  20.30         140.0   83   109.0    8.40     3.40             2
# 15  17.80         302.0  129   220.0    8.00     3.00             2
# 16  14.39         500.0  190   360.0    8.50     2.73             4
# 17  14.89         440.0  215   330.0    8.20     2.71             4
# 18  17.80         350.0  155   250.0    8.50     3.08             4
# 19  16.41         318.0  145   255.0    8.50     2.45             2
# 20  23.54         231.0  110   175.0    8.00     2.56             2
# 21  21.47         360.0  180   290.0    8.40     2.45             2
# 22  16.59         400.0  185     NaN    7.60     3.08             4
# 23  31.90          96.9   75    83.0    9.00     4.30             2
# 24  29.40         140.0   86     NaN    8.00     2.92             2
# 25  13.27         460.0  223   366.0    8.00     3.00             4
# 26  23.90         133.6   96   120.0    8.40     3.91             2
# 27  19.73         318.0  140   255.0    8.50     2.71             2
# 28  13.90         351.0  148   243.0    8.00     3.25             2
# 29  13.27         351.0  148   243.0    8.00     3.26             2
# 30  13.77         360.0  195   295.0    8.25     3.15             4
# 31  16.50         360.0  165   255.0    8.50     2.73             4
#
#     NoOfSpeed  length  width  weight  automatic
# 0           3   200.3   69.9    3910          1
# 1           3   199.6   72.9    3860          1
# 2           3   196.7   72.2    3510          1
# 3           3   199.9   74.0    3890          1
# 4           3   194.1   71.8    3365          0
# 5           3   184.5   69.0    4215          1
# 6           3   179.3   65.4    3020          1
# 7           3   179.3   65.4    3180          1
# 8           4   155.7   64.0    1905          0
# 9           5   165.2   65.0    2320          0
# 10          3   195.4   74.4    3885          1
# 11          4   160.6   62.2    2009          0
# 12          4   170.4   66.9    2655          0
# 13          3   171.5   77.0    3375          1
# 14          4   168.8   69.4    2700          0
# 15          3   199.9   74.0    3890          1
# 16          3   224.1   79.8    5290          1
# 17          3   231.0   79.7    5185          1
# 18          3   196.7   72.2    3910          1
# 19          3   197.6   71.0    3660          1
# 20          3   179.3   65.4    3050          1
# 21          3   214.2   76.3    4250          1
# 22          3   196.0   73.0    3850          1
# 23          5   165.2   61.8    2275          0
# 24          4   176.4   65.4    2150          0
# 25          3   228.0   79.8    5430          1
# 26          5   171.5   63.4    2535          0
# 27          3   215.3   76.3    4370          1
# 28          3   215.5   78.5    4540          1
# 29          3   216.1   78.5    4715          1
# 30          3   209.3   77.4    4215          1
# 31          3   185.2   69.0    3660          1

# %%
df_cars.head(3)
# Out:
#     mpg  displacement   hp  torque  CRatio  RARatio  CarbBarrells  NoOfSpeed  \
# 0  18.9         350.0  165   260.0    8.00     2.56             4          3
# 1  17.0         350.0  170   275.0    8.50     2.56             4          3
# 2  20.0         250.0  105   185.0    8.25     2.73             1          3
#
#    length  width  weight  automatic
# 0   200.3   69.9    3910          1
# 1   199.6   72.9    3860          1
# 2   196.7   72.2    3510          1

# %%
df_cars.describe()
# Out:
#              mpg  displacement         hp      torque     CRatio    RARatio  \
# count  32.000000     32.000000   32.00000   30.000000  32.000000  32.000000
# mean   20.223125    285.043750  136.87500  217.900000   8.281250   3.055312
# std     6.318289    117.240214   44.98082   83.069705   0.300738   0.512338
# min    11.200000     85.300000   70.00000   81.000000   7.600000   2.450000
# 25%    16.477500    211.500000  102.75000  171.250000   8.000000   2.710000
# 50%    19.300000    318.000000  141.50000  243.000000   8.250000   3.000000
# 75%    21.655000    353.250000  166.25000  258.750000   8.500000   3.227500
# max    36.500000    500.000000  223.00000  366.000000   9.000000   4.300000
#
#        CarbBarrells  NoOfSpeed      length      width       weight  automatic
# count     32.000000  32.000000   32.000000  32.000000    32.000000  32.000000
# mean       2.593750   3.343750  191.956250  71.281250  3586.687500   0.718750
# std        1.073414   0.653002   20.548572   5.603077   947.943187   0.456803
# min        1.000000   3.000000  155.700000  61.800000  1905.000000   0.000000
# 25%        2.000000   3.000000  175.175000  65.400000  2940.000000   0.000000
# 50%        2.000000   3.000000  195.700000  72.000000  3755.000000   1.000000
# 75%        4.000000   3.250000  202.550000  76.300000  4215.000000   1.000000
# max        4.000000   5.000000  231.000000  79.800000  5430.000000   1.000000

# %%
df_cars[["hp","mpg"]].describe()
# Out:
#               hp        mpg
# count   32.00000  32.000000
# mean   136.87500  20.223125
# std     44.98082   6.318289
# min     70.00000  11.200000
# 25%    102.75000  16.477500
# 50%    141.50000  19.300000
# 75%    166.25000  21.655000
# max    223.00000  36.500000

# %%
df_cars.tail(3)
# Out:
#       mpg  displacement   hp  torque  CRatio  RARatio  CarbBarrells  \
# 29  13.27         351.0  148   243.0    8.00     3.26             2
# 30  13.77         360.0  195   295.0    8.25     3.15             4
# 31  16.50         360.0  165   255.0    8.50     2.73             4
#
#     NoOfSpeed  length  width  weight  automatic
# 29          3   216.1   78.5    4715          1
# 30          3   209.3   77.4    4215          1
# 31          3   185.2   69.0    3660          1

# %%
df_cars.dtypes
# Out:
# mpg             float64
# displacement    float64
# hp                int64
# torque          float64
# CRatio          float64
# RARatio         float64
# CarbBarrells      int64
# NoOfSpeed         int64
# length          float64
# width           float64
# weight            int64
# automatic         int64
# dtype: object

# %% [markdown]
# ### 3-Labelled Indexing

# %%
#df_cars.ix[5] # not df_cars[0] This method is deprecated

# %%
df_cars.iloc[5]
# Out:
# mpg               11.20
# displacement     440.00
# hp               215.00
# torque           330.00
# CRatio             8.20
# RARatio            2.88
# CarbBarrells       4.00
# NoOfSpeed          3.00
# length           184.50
# width             69.00
# weight          4215.00
# automatic          1.00
# Name: 5, dtype: float64

# %%
df_cars.loc[5]
# Out:
# mpg               11.20
# displacement     440.00
# hp               215.00
# torque           330.00
# CRatio             8.20
# RARatio            2.88
# CarbBarrells       4.00
# NoOfSpeed          3.00
# length           184.50
# width             69.00
# weight          4215.00
# automatic          1.00
# Name: 5, dtype: float64

# %%
df_cars.mpg.head() # This is a Series
# Out:
# 0    18.90
# 1    17.00
# 2    20.00
# 3    18.25
# 4    20.07
# Name: mpg, dtype: float64

# %%
df_cars['mpg'].tail()
# Out:
# 27    19.73
# 28    13.90
# 29    13.27
# 30    13.77
# 31    16.50
# Name: mpg, dtype: float64

# %%
df_cars[["mpg","hp"]].tail() # Anywhere a column lable is expected, we can give a list of names
# Out:
#       mpg   hp
# 27  19.73  140
# 28  13.90  148
# 29  13.27  148
# 30  13.77  195
# 31  16.50  165

# %% [markdown]
# ## 4 - NaN Missing Values

# %%
df_cars.dropna()
# Out:
#       mpg  displacement   hp  torque  CRatio  RARatio  CarbBarrells  \
# 0   18.90         350.0  165   260.0    8.00     2.56             4
# 1   17.00         350.0  170   275.0    8.50     2.56             4
# 2   20.00         250.0  105   185.0    8.25     2.73             1
# 3   18.25         351.0  143   255.0    8.00     3.00             2
# 4   20.07         225.0   95   170.0    8.40     2.76             1
# 5   11.20         440.0  215   330.0    8.20     2.88             4
# 6   22.12         231.0  110   175.0    8.00     2.56             2
# 7   21.47         262.0  110   200.0    8.50     2.56             2
# 8   34.70          89.7   70    81.0    8.20     3.90             2
# 9   30.40          96.9   75    83.0    9.00     4.30             2
# 10  16.50         350.0  155   250.0    8.50     3.08             4
# 11  36.50          85.3   80    83.0    8.50     3.89             2
# 12  21.50         171.0  109   146.0    8.20     3.22             2
# 13  19.70         258.0  110   195.0    8.00     3.08             1
# 14  20.30         140.0   83   109.0    8.40     3.40             2
# 15  17.80         302.0  129   220.0    8.00     3.00             2
# 16  14.39         500.0  190   360.0    8.50     2.73             4
# 17  14.89         440.0  215   330.0    8.20     2.71             4
# 18  17.80         350.0  155   250.0    8.50     3.08             4
# 19  16.41         318.0  145   255.0    8.50     2.45             2
# 20  23.54         231.0  110   175.0    8.00     2.56             2
# 21  21.47         360.0  180   290.0    8.40     2.45             2
# 23  31.90          96.9   75    83.0    9.00     4.30             2
# 25  13.27         460.0  223   366.0    8.00     3.00             4
# 26  23.90         133.6   96   120.0    8.40     3.91             2
# 27  19.73         318.0  140   255.0    8.50     2.71             2
# 28  13.90         351.0  148   243.0    8.00     3.25             2
# 29  13.27         351.0  148   243.0    8.00     3.26             2
# 30  13.77         360.0  195   295.0    8.25     3.15             4
# 31  16.50         360.0  165   255.0    8.50     2.73             4
#
#     NoOfSpeed  length  width  weight  automatic
# 0           3   200.3   69.9    3910          1
# 1           3   199.6   72.9    3860          1
# 2           3   196.7   72.2    3510          1
# 3           3   199.9   74.0    3890          1
# 4           3   194.1   71.8    3365          0
# 5           3   184.5   69.0    4215          1
# 6           3   179.3   65.4    3020          1
# 7           3   179.3   65.4    3180          1
# 8           4   155.7   64.0    1905          0
# 9           5   165.2   65.0    2320          0
# 10          3   195.4   74.4    3885          1
# 11          4   160.6   62.2    2009          0
# 12          4   170.4   66.9    2655          0
# 13          3   171.5   77.0    3375          1
# 14          4   168.8   69.4    2700          0
# 15          3   199.9   74.0    3890          1
# 16          3   224.1   79.8    5290          1
# 17          3   231.0   79.7    5185          1
# 18          3   196.7   72.2    3910          1
# 19          3   197.6   71.0    3660          1
# 20          3   179.3   65.4    3050          1
# 21          3   214.2   76.3    4250          1
# 23          5   165.2   61.8    2275          0
# 25          3   228.0   79.8    5430          1
# 26          5   171.5   63.4    2535          0
# 27          3   215.3   76.3    4370          1
# 28          3   215.5   78.5    4540          1
# 29          3   216.1   78.5    4715          1
# 30          3   209.3   77.4    4215          1
# 31          3   185.2   69.0    3660          1

# %%
df_cars.dropna().describe()
# Out:
#              mpg  displacement          hp      torque     CRatio    RARatio  \
# count  30.000000     30.000000   30.000000   30.000000  30.000000  30.000000
# mean   20.038333    286.046667  136.966667  217.900000   8.313333   3.059000
# std     6.267335    116.237049   44.650739   83.069705   0.277282   0.529081
# min    11.200000     85.300000   70.000000   81.000000   8.000000   2.450000
# 25%    16.432500    226.500000  106.000000  171.250000   8.000000   2.710000
# 50%    19.300000    318.000000  141.500000  243.000000   8.325000   3.000000
# 75%    21.492500    351.000000  165.000000  258.750000   8.500000   3.242500
# max    36.500000    500.000000  223.000000  366.000000   9.000000   4.300000
#
#        CarbBarrells  NoOfSpeed      length      width       weight  automatic
# count     30.000000  30.000000   30.000000  30.000000    30.000000  30.000000
# mean       2.566667   3.333333  192.340000  71.420000  3625.800000   0.733333
# std        1.072648   0.660895   21.031005   5.678477   940.967712   0.449776
# min        1.000000   3.000000  155.700000  61.800000  1905.000000   0.000000
# 25%        2.000000   3.000000  173.450000  65.775000  3027.500000   0.250000
# 50%        2.000000   3.000000  196.050000  72.000000  3760.000000   1.000000
# 75%        4.000000   3.000000  207.050000  76.300000  4215.000000   1.000000
# max        4.000000   5.000000  231.000000  79.800000  5430.000000   1.000000

# %% [markdown]
# ### Link to pandas documentation: https://pandas.pydata.org/pandas-docs/stable/reference

# %%
# Compare these two to see difference in statistics with NA values being typecasted to numeric with skipna.
# When summing data, NA (missing) values will be treated as zero.
# If the data are all NA, the result will be 0.
##df_cars[['mpg','displacement','torque']].cumprod()
##df_cars[['mpg','displacement','torque']].cumprod(skipna=False)

# Compare these two to see difference in string replacement with NA values being replaced to custom string.
# In these two lines NA is replaced with EXAMPLE
##df_cars[['torque','mpg']]
##df_cars[['torque','mpg']].fillna('EXAMPLE')

# Interpolate - come back to this later, looks like it's very important in smoothing missing data sets 
# DataFrame.interpolate(method='linear', axis=0, limit=None, inplace=False, limit_direction=None, 
#                       limit_area=None, downcast=None, **kwargs)

df_cars_interpoloated = df_cars.interpolate(method='linear', axis=0, limit=None, inplace=False, limit_direction=None, limit_area=None, downcast=None)
df_cars['torque'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df_cars_interpoloated['torque'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ### Very Interesting parallel parking maneuver by Brandon Rhodes
# #### Ref: Pandas From The Ground Up - PyCon 2015 https://www.youtube.com/watch?v=5JnMutdy6Fw

# %%
sales = pd.read_csv("data/movies/sales2.csv")
sales = sales.fillna('')

# %%
sales
# Out:
#                                Title Units sold List price Royalty
# 0
# 1                Sales report for Q4
# 2             E-Book Reader US Store
# 3   Pining for the Fisheries of Yore       80.0        3.5   14.98
# 4                           Swimrand        1.0       2.99    0.14
# 5             The Bricklayer's Bible       17.0        3.5    5.15
# 6                 The Duck Goes Here       34.0       2.99    5.78
# 7        The Tower Commission Report        4.0        9.5     6.2
# 8                 US royalties (USD)                         32.25
# 9
# 10
# 11               Sales report for Q4
# 12            E-Book Reader UK Store
# 13  Pining for the Fisheries of Yore       47.0       2.99   11.98
# 14            The Bricklayer's Bible       17.0       2.99     3.5
# 15       The Tower Commission Report        4.0        6.5     4.8
# 16                UK royalties (GBP)                         20.28
# 17
# 18
# 19               Sales report for Q4
# 20        E-Book Reader France Store
# 21                          Swimrand        8.0       1.99    0.88
# 22                The Duck Goes Here       12.0       1.99     1.5
# 23            France royalties (EUR)                          2.38

# %% [markdown]
# ### Challenge:
# ####   First combine these sales together into a single dataframe,
# ####   Then compute how much money consumers spent on each book in each currency.

# %%
sales = pd.read_csv("data/movies/sales2.csv")
sales = sales.dropna(subset=['Royalty'])
sales
# Out:
#                                Title  Units sold  List price  Royalty
# 3   Pining for the Fisheries of Yore        80.0        3.50    14.98
# 4                           Swimrand         1.0        2.99     0.14
# 5             The Bricklayer's Bible        17.0        3.50     5.15
# 6                 The Duck Goes Here        34.0        2.99     5.78
# 7        The Tower Commission Report         4.0        9.50     6.20
# 8                 US royalties (USD)         NaN         NaN    32.25
# 13  Pining for the Fisheries of Yore        47.0        2.99    11.98
# 14            The Bricklayer's Bible        17.0        2.99     3.50
# 15       The Tower Commission Report         4.0        6.50     4.80
# 16                UK royalties (GBP)         NaN         NaN    20.28
# 21                          Swimrand         8.0        1.99     0.88
# 22                The Duck Goes Here        12.0        1.99     1.50
# 23            France royalties (EUR)         NaN         NaN     2.38

# %%
sales.head()
# Out:
#                               Title  Units sold  List price  Royalty
# 3  Pining for the Fisheries of Yore        80.0        3.50    14.98
# 4                          Swimrand         1.0        2.99     0.14
# 5            The Bricklayer's Bible        17.0        3.50     5.15
# 6                The Duck Goes Here        34.0        2.99     5.78
# 7       The Tower Commission Report         4.0        9.50     6.20

# %%
sales['Consumer Spent'] = sales['Units sold'] * sales['List price']
sales
# Out:
#                                Title  Units sold  List price  Royalty  \
# 3   Pining for the Fisheries of Yore        80.0        3.50    14.98
# 4                           Swimrand         1.0        2.99     0.14
# 5             The Bricklayer's Bible        17.0        3.50     5.15
# 6                 The Duck Goes Here        34.0        2.99     5.78
# 7        The Tower Commission Report         4.0        9.50     6.20
# 8                 US royalties (USD)         NaN         NaN    32.25
# 13  Pining for the Fisheries of Yore        47.0        2.99    11.98
# 14            The Bricklayer's Bible        17.0        2.99     3.50
# 15       The Tower Commission Report         4.0        6.50     4.80
# 16                UK royalties (GBP)         NaN         NaN    20.28
# 21                          Swimrand         8.0        1.99     0.88
# 22                The Duck Goes Here        12.0        1.99     1.50
# 23            France royalties (EUR)         NaN         NaN     2.38
#
#     Consumer Spent
# 3           280.00
# 4             2.99
# 5            59.50
# 6           101.66
# 7            38.00
# 8              NaN
# 13          140.53
# 14           50.83
# 15           26.00
# 16             NaN
# 21           15.92
# 22           23.88
# 23             NaN

# %%
# painfully very hard to do without regular expressions

# sales.Currency won't work
sales['Currency'] = sales.Title.str.extract(r'\((.*)\)').fillna(method='bfill') 
#.fillna('') 
#.fillna(method='bfill')
# bfill is for back-fillpyth
sales
# Out:
#                                Title  Units sold  List price  Royalty  \
# 3   Pining for the Fisheries of Yore        80.0        3.50    14.98
# 4                           Swimrand         1.0        2.99     0.14
# 5             The Bricklayer's Bible        17.0        3.50     5.15
# 6                 The Duck Goes Here        34.0        2.99     5.78
# 7        The Tower Commission Report         4.0        9.50     6.20
# 8                 US royalties (USD)         NaN         NaN    32.25
# 13  Pining for the Fisheries of Yore        47.0        2.99    11.98
# 14            The Bricklayer's Bible        17.0        2.99     3.50
# 15       The Tower Commission Report         4.0        6.50     4.80
# 16                UK royalties (GBP)         NaN         NaN    20.28
# 21                          Swimrand         8.0        1.99     0.88
# 22                The Duck Goes Here        12.0        1.99     1.50
# 23            France royalties (EUR)         NaN         NaN     2.38
#
#     Consumer Spent Currency
# 3           280.00      USD
# 4             2.99      USD
# 5            59.50      USD
# 6           101.66      USD
# 7            38.00      USD
# 8              NaN      USD
# 13          140.53      GBP
# 14           50.83      GBP
# 15           26.00      GBP
# 16             NaN      GBP
# 21           15.92      EUR
# 22           23.88      EUR
# 23             NaN      EUR

# %% [markdown]
# ## 5-Statistics

# %%
df_cars.min()
# Out:
# mpg               11.20
# displacement      85.30
# hp                70.00
# torque            81.00
# CRatio             7.60
# RARatio            2.45
# CarbBarrells       1.00
# NoOfSpeed          3.00
# length           155.70
# width             61.80
# weight          1905.00
# automatic          0.00
# dtype: float64

# %%
df_cars.quantile()
# Out:
# mpg               19.30
# displacement     318.00
# hp               141.50
# torque           243.00
# CRatio             8.25
# RARatio            3.00
# CarbBarrells       2.00
# NoOfSpeed          3.00
# length           195.70
# width             72.00
# weight          3755.00
# automatic          1.00
# Name: 0.5, dtype: float64

# %%
df_cars.corr()
# Out:
#                    mpg  displacement        hp    torque    CRatio   RARatio  \
# mpg           1.000000     -0.878790 -0.806880 -0.849592  0.356548  0.594786
# displacement -0.878790      1.000000  0.945208  0.989163 -0.330154 -0.631597
# hp           -0.806880      0.945208  1.000000  0.964359 -0.292058 -0.517043
# torque       -0.849592      0.989163  0.964359  1.000000 -0.325999 -0.672866
# CRatio        0.356548     -0.330154 -0.292058 -0.325999  1.000000  0.373746
# RARatio       0.594786     -0.631597 -0.517043 -0.672866  0.373746  1.000000
# CarbBarrells -0.486997      0.659060  0.771910  0.653126 -0.049339 -0.205352
# NoOfSpeed     0.722006     -0.781478 -0.643156 -0.746180  0.493810  0.842862
# length       -0.754622      0.855198  0.797389  0.864122 -0.258108 -0.548123
# width        -0.773111      0.801397  0.717606  0.788128 -0.318764 -0.434358
# weight       -0.862927      0.945662  0.883400  0.943487 -0.277218 -0.542425
# automatic    -0.745053      0.835424  0.726684  0.801277 -0.368361 -0.703249
#
#               CarbBarrells  NoOfSpeed    length     width    weight  automatic
# mpg              -0.486997   0.722006 -0.754622 -0.773111 -0.862927  -0.745053
# displacement      0.659060  -0.781478  0.855198  0.801397  0.945662   0.835424
# hp                0.771910  -0.643156  0.797389  0.717606  0.883400   0.726684
# torque            0.653126  -0.746180  0.864122  0.788128  0.943487   0.801277
# CRatio           -0.049339   0.493810 -0.258108 -0.318764 -0.277218  -0.368361
# RARatio          -0.205352   0.842862 -0.548123 -0.434358 -0.542425  -0.703249
# CarbBarrells      1.000000  -0.300575  0.425188  0.315673  0.520642   0.417338
# NoOfSpeed        -0.300575   1.000000 -0.663080 -0.668237 -0.717826  -0.854998
# length            0.425188  -0.663080  1.000000  0.884977  0.947586   0.686308
# width             0.315673  -0.668237  0.884977  1.000000  0.901543   0.650721
# weight            0.520642  -0.717826  0.947586  0.901543  1.000000   0.772228
# automatic         0.417338  -0.854998  0.686308  0.650721  0.772228   1.000000

# %%
df_cars.cov() # covariance
# Out:
#                       mpg   displacement            hp        torque  \
# mpg             39.920777    -650.970077   -229.316694   -442.319138
# displacement  -650.970077   13745.267702   4984.612097   9551.135862
# hp            -229.316694    4984.612097   2023.274194   3576.927586
# torque        -442.319138    9551.135862   3576.927586   6900.575862
# CRatio           0.677496     -11.640766     -3.950806     -7.508966
# RARatio          1.925383     -37.937885    -11.915444    -29.572862
# CarbBarrells    -3.302883      82.940927     37.270161     58.196552
# NoOfSpeed        2.978891     -59.828427    -18.891129    -40.965517
# length         -97.973891    2060.273911    737.020161   1509.655862
# width          -27.369552     526.442782    180.858871    371.767586
# weight       -5168.395121  105098.107661  37667.540323  73748.531034
# automatic       -2.150383      44.741734     14.931452     29.937931
#
#                  CRatio     RARatio  CarbBarrells   NoOfSpeed        length  \
# mpg            0.677496    1.925383     -3.302883    2.978891    -97.973891
# displacement -11.640766  -37.937885     82.940927  -59.828427   2060.273911
# hp            -3.950806  -11.915444     37.270161  -18.891129    737.020161
# torque        -7.508966  -29.572862     58.196552  -40.965517   1509.655862
# CRatio         0.090444    0.057587     -0.015927    0.096976     -1.595040
# RARatio        0.057587    0.262490     -0.112933    0.281986     -5.770534
# CarbBarrells  -0.015927   -0.112933      1.152218   -0.210685      9.378427
# NoOfSpeed      0.096976    0.281986     -0.210685    0.426411     -8.897379
# length        -1.595040   -5.770534      9.378427   -8.897379    422.243831
# width         -0.537137   -1.246897      1.898589   -2.444960    101.892056
# weight       -79.030242 -263.437964    529.772177 -444.340726  18457.911694
# automatic     -0.050605   -0.164587      0.204637   -0.255040      6.442137
#
#                     width         weight   automatic
# mpg            -27.369552   -5168.395121   -2.150383
# displacement   526.442782  105098.107661   44.741734
# hp             180.858871   37667.540323   14.931452
# torque         371.767586   73748.531034   29.937931
# CRatio          -0.537137     -79.030242   -0.050605
# RARatio         -1.246897    -263.437964   -0.164587
# CarbBarrells     1.898589     529.772177    0.204637
# NoOfSpeed       -2.444960    -444.340726   -0.255040
# length         101.892056   18457.911694    6.442137
# width           31.394476    4788.455242    1.665524
# weight        4788.455242  898596.286290  334.393145
# automatic        1.665524     334.393145    0.208669

# %% [markdown]
# ### Calculate & Plot Correlations

# %%
df_cars.hp.corr(df_cars.weight)
# Out:
# 0.8834003785623671

# %%
from ggplot import *
# %matplotlib inline

ggplot(df_cars, aes(x='hp', y='weight')) +\
  geom_point() + labs(title="Car-Attributes", x="Horsepower", y="Weight")
# Out:
# <ggplot: (8730391590738)>

# %%
df_cars.plot(x="hp",y="weight",kind="scatter")
# Out:
# <AxesSubplot:xlabel='hp', ylabel='weight'>

# %% [markdown]
# ### Coding Excrcise
# 1. Calculate the correlation between Rear Axle Ratio & the Width
# 2. Plot & verify

# %%
print('%2.3f' % df_cars.RARatio.corr(df_cars.width, method="pearson"))
print('%2.3f' % df_cars.RARatio.corr(df_cars.width, method="spearman"))
#-0.453
#-0.244
# Out:
# -0.434
# -0.224

# %%
from ggplot import *
# %matplotlib inline
ggplot(df_cars, aes(x='RARatio', y='width')) +\
  geom_point() + labs(title="Car-Attributes", x="RA Ratio", y="Width")
# Out:
# <ggplot: (8730391377089)>

# %% [markdown]
# ### 6-GroupBy

# %%
df_cars.groupby("NoOfSpeed").mean()["mpg"].to_frame()
# Out:
#                  mpg
# NoOfSpeed
# 3          17.439167
# 4          28.480000
# 5          28.733333

# %%
df_cars.groupby("NoOfSpeed").mean()[["weight","hp","torque","mpg"]] #List of column names
# Out:
#                 weight          hp      torque        mpg
# NoOfSpeed
# 3          4009.375000  154.416667  253.565217  17.439167
# 4          2283.800000   85.600000  104.750000  28.480000
# 5          2376.666667   82.000000   95.333333  28.733333

# %% [markdown]
# ## That is All Folks !
